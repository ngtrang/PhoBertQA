# %%
# %%time
# !python main_phobert.py --path_train_data './dataset/preprocess_dataset/train_ZALO.csv' \
--path_test_data './dataset/preprocess_dataset/test_ZALO.csv' \
--path_log_file './save_model/phobert.txt' \
--output_dir './save_model/phobert' \
--max_seq_length 256 \
--batch_size 20 \
--patience 10 \
--save_steps 30 \
--learning_rate 3e-5 \
--device 'cuda:2' \
--load_data_from_pt
# Out:
# Loading codes from ./PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Start loading dataset ...
# Load train dataset done !!!
# Training ...
#
# ...
# /home/dle/anaconda3/envs/news/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
#
# Epoch: 1	Step: 30	LR: 2.9e-05
#
# Train result:	Loss: 0.001	Acc: 0.6657	F1: 0.2096
#
# ...
# Test result:	Loss: 0.0281	Acc: 0.742	F1: [[0.4246]]
#
# ________________________________________________________________
#
# Epoch: 1	Step: 60	LR: 2.8e-05
#
# Train result:	Loss: 0.002	Acc: 0.692	F1: 0.3309
#
# ...
# Test result:	Loss: 0.0228	Acc: 0.7886	F1: [[0.4516]]
#
# ________________________________________________________________
# Test loss decreased (inf --> 0.023)
#
# Epoch: 1	Step: 90	LR: 2.7e-05
#
# Train result:	Loss: 0.0028	Acc: 0.7169	F1: 0.4115
#
# ...

# %%
# %%time
# !python main_phobert.py --path_train_data './dataset/preprocess_dataset/train_ZALO.csv' \
--path_test_data './dataset/preprocess_dataset/test_ZALO.csv' \
--path_log_file './save_model/phobert.txt' \
--output_dir './save_model/phobert' \
--max_seq_length 256 \
--batch_size 20 \
--patience 10 \
--save_steps 30 \
--learning_rate 3e-5 \
--device 'cuda:2' \
--load_data_from_pt
# Out:
# Loading codes from ./PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Start loading dataset ...
# Load train dataset done !!!
# Training ...
#
# ...
#
# Epoch: 1	Step: 30	LR: 2.9e-05
#
# Train result:	Loss: 0.001	Acc: 0.6723	F1: 0.176
#
# ...
# Test result:	Loss: 0.0271	Acc: 0.7625	F1: [[0.3402]]
#
# ________________________________________________________________
#
# Epoch: 1	Step: 60	LR: 2.8e-05
#
# Train result:	Loss: 0.002	Acc: 0.6933	F1: 0.3419
#
# ...
# Test result:	Loss: 0.0228	Acc: 0.7965	F1: [[0.4555]]
#
# ________________________________________________________________
# Test loss decreased (inf --> 0.023)
#
# Epoch: 1	Step: 90	LR: 2.7e-05
#
# Train result:	Loss: 0.0027	Acc: 0.7242	F1: 0.4328
#
# ...
# Test result:	Loss: 0.0225	Acc: 0.7879	F1: [[0.6635]]
#
# ________________________________________________________________
# Test loss decreased (0.023 --> 0.022)
#
# Epoch: 1	Step: 120	LR: 2.6e-05
#
# Train result:	Loss: 0.0034	Acc: 0.7466	F1: 0.5032
#
# ...

# %%
# %%time
# !python main_phobert.py --path_train_data './dataset/preprocess_dataset/train_ZALO.csv' \
--path_test_data './dataset/preprocess_dataset/test_ZALO.csv' \
--path_log_file './save_model/phobert.txt' \
--output_dir './save_model/phobert' \
--max_seq_length 256 \
--batch_size 20 \
--patience 10 \
--save_steps 30 \
--learning_rate 3e-5 \
--device 'cuda:2' \
--load_data_from_pt
# Out:
# Loading codes from ./PhoBERT_base_transformers/bpe.codes ...
# Read 64000 codes from the codes file.
# Start loading dataset ...
# Load train dataset done !!!
# Training ...
#
# ...
#
# Epoch: 1	Step: 30	LR: 2.9e-05
#
# Train result:	Loss: 0.001	Acc: 0.6637	F1: 0.1599
#
# ...
# Test result:	Loss: 0.0267	Acc: 0.7535	F1: [[0.1624]]
#
# ________________________________________________________________
#
# Epoch: 1	Step: 60	LR: 2.8e-05
#
# Train result:	Loss: 0.002	Acc: 0.6913	F1: 0.3295
#
# ...
# Test result:	Loss: 0.0227	Acc: 0.798	F1: [[0.6457]]
#
# ________________________________________________________________
# Test loss decreased (inf --> 0.023)
#
# Epoch: 1	Step: 90	LR: 2.7e-05
#
# Train result:	Loss: 0.0028	Acc: 0.7219	F1: 0.4356
#
# ...
# Test result:	Loss: 0.0228	Acc: 0.7823	F1: [[0.6137]]
#
# ________________________________________________________________
# EarlyStopping counter: 1 out of 10
#
# Epoch: 1	Step: 120	LR: 2.6e-05
#
# Train result:	Loss: 0.0035	Acc: 0.7396	F1: 0.4921
#
# ...
